# %% [markdown]
# # Baseline Model Notes
#
# This notebook is intentionally lightweight. The authoritative baseline workflow is implemented in `src/train.py` so the project remains reproducible from the command line, CI and Docker-oriented workflows.
#
# Use this notebook only for exploratory notes or visual inspection while keeping model training logic in versioned Python modules.

# %% [markdown]
# ## Reproducible commands
#
# From the project root:
#
# ```bash
# python -m src.train --model both --threshold 0.55
# python -m src.visualize_results
# python -m src.analyze_random_forest
# ```

# %%
# Exploratory baseline checks can be added here.
# Keep reusable training code in src/ so it can be tested and run in CI.
